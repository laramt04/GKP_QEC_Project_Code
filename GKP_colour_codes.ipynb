# %% [markdown]
# start with the 2d colour code then the 3d one
#
# chromobius decoder rather than pymatching
# this is bc single errors
#
# [[7, 1, 3]] smallest colour code
# [[15, 1, 3]] 3d tetraherdral colour code
#
# CSS codes family defined on a particular d dims graph

# %%
#make the parity check matricies 

def colour_rep_code(d):
    

    
    return
